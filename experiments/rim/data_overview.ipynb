# %% [markdown]
# # RIM Experiment Overview
#
# Lists all recorded runs and their key parameters.

# %%
import pandas as pd
from rim_teleop.data import ExperimentRegistry

DATA_DIR = "/home/athena/csirois/data/franka/rim"

registry = ExperimentRegistry(DATA_DIR)
runs = registry.list_runs()
print(f"{len(runs)} runs found in {DATA_DIR}")
# Out:
# 72 runs found in /home/athena/csirois/data/franka/rim

# %%
summary_df = pd.DataFrame([r.summary() for r in runs])
summary_df
# Out:
#                    name           created_at rim_enabled force_feedback  \
# 0   run_20260522_161725  2026-05-22 16:17:25        True            rim
# 1   run_20260522_160954  2026-05-22 16:09:54        True            rim
# 2   run_20260522_155110  2026-05-22 15:51:10        True            rim
# 3   run_20260522_154437  2026-05-22 15:44:37        True            rim
# 4   run_20260522_154225  2026-05-22 15:42:25        True            rim
# ..                  ...                  ...         ...            ...
# 67  run_20260424_122854  2026-04-24 12:28:54        None            NaN
# 68  run_20260424_122824  2026-04-24 12:28:24        None            NaN
# 69  run_20260424_122742  2026-04-24 12:27:42        None            NaN
# 70  run_20260424_122143  2026-04-24 12:21:43        None            NaN
# 71  run_20260424_121938  2026-04-24 12:19:38        None            NaN
#
#     stiffness  damping  contact_surface  haptic_hz  control_hz  \
# 0      1000.0     90.0             0.03     1000.0        50.0
# 1      1000.0     90.0             0.03     1000.0        50.0
# 2      1000.0     90.0             0.03     1000.0        50.0
# 3      1000.0     90.0             0.03     1000.0        50.0
# 4      1000.0     90.0             0.03     1000.0        50.0
# ..        ...      ...              ...        ...         ...
# 67     1000.0     90.0             0.00     1000.0        50.0
# 68     1000.0     90.0             0.00     1000.0        50.0
# 69     1000.0     90.0             0.00     1000.0        50.0
# 70     1000.0     90.0             0.00     1000.0        50.0
# 71     1000.0     90.0             0.00     1000.0        50.0
#
#       tool_tip_offset
# 0   [0.0, 0.0, 0.043]
# 1   [0.0, 0.0, 0.043]
# 2   [0.0, 0.0, 0.043]
# 3   [0.0, 0.0, 0.043]
# 4   [0.0, 0.0, 0.043]
# ..                ...
# 67               None
# 68               None
# 69               None
# 70               None
# 71               None
#
# [72 rows x 10 columns]

# %% [markdown]
# ## Filter runs

# %%
# Example: only RIM-enabled runs with force feedback
filtered = summary_df[summary_df["rim_enabled"] == True]
filtered
# Out:
#                    name           created_at rim_enabled force_feedback  \
# 0   run_20260522_161725  2026-05-22 16:17:25        True            rim
# 1   run_20260522_160954  2026-05-22 16:09:54        True            rim
# 2   run_20260522_155110  2026-05-22 15:51:10        True            rim
# 3   run_20260522_154437  2026-05-22 15:44:37        True            rim
# 4   run_20260522_154225  2026-05-22 15:42:25        True            rim
# 5   run_20260521_160401  2026-05-21 16:04:01        True            rim
# 8   run_20260521_155836  2026-05-21 15:58:37        True          robot
# 9   run_20260521_155251  2026-05-21 15:52:51        True            rim
# 8   [0.0, 0.0, 0.043]
# 9   [0.0, 0.0, 0.043]
# 10  [0.0, 0.0, 0.043]
# 11  [0.0, 0.0, 0.043]
# 12  [0.0, 0.0, 0.043]
# 13  [0.0, 0.0, 0.043]
# 14  [0.0, 0.0, 0.043]
# 15  [0.0, 0.0, 0.043]
# 16  [0.0, 0.0, 0.043]
# 17  [0.0, 0.0, 0.043]
# 18               None
# 19               None
# 20               None
# 21               None
# 22               None
# 23               None
# 24               None
# 25               None
# 26               None
# 27               None
# 29               None

# %% [markdown]
# ## Full config of a specific run

# %%
import json

run = registry.latest()  # or registry.get("run_20260521_160401")
print(json.dumps(run.config, indent=2))
# Out:
# {
#   "rates": {
#     "control_rate_hz": 50.0,
#     "model_rate_hz": 50.0,
#     "rim_rate_hz": 1000.0,
#     "haptic_rate_hz": 1000.0
#   },
#   "interface": {
#     "axis": "z",
#     "stiffness": 1000.0,
#     "damping": 90.0,
#     "contact_surface": 0.03,
#     "contact_stiffness": 10000.0,
#     "contact_damping": 100.0,
#     "force_scale": 0.1,
#     "force_cap": 12.0,
#     "rim_enabled": true,
#     "force_feedback": "rim"
#   },
#   "safety": {
#     "stale_state_timeout_s": 0.2,
#     "stale_model_timeout_s": 0.25,
#     "deadman_required": false
#   },
#   "inverse3": {
#     "uri": "ws://localhost:10001",
#     "scale": 1.0,
#     "i3_origin": [
#       0.0,
#       -0.17,
#       0.16
#     ],
#     "i3_origin_rpy": [
#       0.0,
#       0.0,
#       90.0
#     ],
#     "i3_origin_rpy_degrees": true,
#     "center_on_start": true,
#     "enable_force_feedback": true,
#     "stiffness": 150.0,
#     "force_cap": 12.0,
#     "orientation_default": [
#       0.0,
#       1.0,
#       0.0,
#       0.0
#     ],
#     "interface_axis": "z",
#     "interface_workspace_scale": 1.0,
#     "interface_force_scale": 0.1
#   },
#   "robot": {
#     "namespace": "fr3",
#     "controller_name": "osc_pd_controller",
#     "trajectory_length": 5,
#     "trajectory_dt": 0.1,
#     "wrench_filter_alpha": 0.1
#   },
#   "model": {
#     "urdf_package": "franka_rim",
#     "urdf_relative_path": "models/fr3_franka_hand.urdf",
#     "ee_frame_name": "fr3_hand_tcp",
#     "filter_alpha_q": 0.3,
#     "filter_alpha_q_dot": 0.2,
#     "filter_alpha_tau": 0.2,
#     "tool_tip_offset": [
#       0.0,
#       0.0,
#       0.043
#     ]
#   },
#   "logging": {
#     "enabled": true,
#     "sinks": [
#       "file_sink",
#       "foxglove_sink"
#     ],
#     "file_sink": {
#       "enabled": true,
#       "output_dir": "/home/athena/csirois/data/franka/rim",
#       "run_name": null,
#       "flush_hz": 20.0
#     },
#     "foxglove_sink": {
#       "enabled": true,
#       "host": "0.0.0.0",
#       "port": 8765,
#       "topic_prefix": "/rim"
#     }
#   },
#   "dry_run": false
# }
